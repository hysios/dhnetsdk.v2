# %%
# %matplotlib inline
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np


img = Image.open("../images/20200703-1729180972-1656869358_big.jpg")
plt.imshow(img)
ax = plt.gca()

# left, top, right, bottom = (2741, 627, 3018, 703)
left, top, right, bottom = np.array([ 2765, 724, 3033, 807]) 

cw, cy = right - left, bottom - top
rect = patches.Rectangle((left,top),cw,cy,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
